# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafael-Barbosa/Perceptron_Adaline/blob/main/TLU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TLU

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_line(w1, w2, b):
    x1, x2 = np.meshgrid(np.linspace(0,1,100), np.linspace(0,1,100))
    x_mesh = np.array([x1.ravel(), x2.ravel()]).T
    
    plt.figure(0, figsize=(10,4))
  
    
    
    y_mesh = np.dot(x_mesh, np.array([w1, w2]).T) + b
    y_mesh = np.where(y_mesh <= 0, 0, 1)
   

    plt.contourf(x1, x2, y_mesh.reshape(x1.shape), cmap='bwr')
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.scatter(x[:,0], x[:,1], c=y.ravel(), s=100, cmap='bwr')

    y_pred = np.dot(x, np.array([w1, w2]).T) + b
    y_bin = np.where(y_pred <= 0, 0, 1)
    print('{0} => {1}'.format(y_pred, y_bin))
 
   
    plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[1, 0, 0, 1]]).T

print(x, y, sep='\n')
# Out:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# [[1]
#  [0]
#  [0]
#  [1]]

# %%
plt.scatter(x[:,0], x[:,1], c=y.ravel(), s=100, cmap='bwr')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
D = x.shape[1]
w = 2*np.random.random(size=D)-1
b = 2*np.random.random()-1

learning_rate=0.01

for step in range(101):
    cost = 0
    for x_n, y_n in zip(x,y):
        y_pred = np.dot(x_n, w) + b 
        y_pred = 1 if y_pred > 0 else 0
        error = y_n - y_pred
        w = w + learning_rate*np.dot(np.squeeze(error), np.squeeze(x_n)) 
        b = b + learning_rate*error
        
    if step % 10 == 0:
        W=np.array(w)
        print('step{0}'.format(step))
        plot_line(w1=W[0],w2=W[1],b=b)


print('w1:',W[0])
print('w2:',W[1])
print('b:',b)
print('y_pred: {0}'.format(np.dot(x,np.array(w))+b))
# Out:
# step0
# [ 0.63692164  0.87428822 -0.19498562  0.04238096] => [1 1 0 1]
# step10
# [ 0.59692164  0.79428822 -0.17498562  0.02238096] => [1 1 0 1]
# step20
# [ 0.55692164  0.71428822 -0.15498562  0.00238096] => [1 1 0 1]
# step30
# [ 0.52692164  0.65428822 -0.11498562  0.01238096] => [1 1 0 1]
# step40
# [ 0.49692164  0.59428822 -0.07498562  0.02238096] => [1 1 0 1]
# step50
# [ 0.45692164  0.51428822 -0.05498562  0.00238096] => [1 1 0 1]
# step60
# [ 0.42692164  0.45428822 -0.01498562  0.01238096] => [1 1 0 1]
# step70
# [0.38692164 0.39428822 0.00501438 0.01238096] => [1 1 1 1]
# step80
# [0.33692164 0.34428822 0.00501438 0.01238096] => [1 1 1 1]
# step90
# [0.28692164 0.29428822 0.00501438 0.01238096] => [1 1 1 1]
# step100
# [0.23692164 0.24428822 0.00501438 0.01238096] => [1 1 1 1]
# w1: -0.23190725456686967
# w2: 0.007366581265383048
# b: [0.23692164]
# y_pred: [0.23692164 0.24428822 0.00501438 0.01238096]
